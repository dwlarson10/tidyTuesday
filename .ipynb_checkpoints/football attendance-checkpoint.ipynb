# %%
import pandas as pd

# %%
## Loading the attendance data
url='https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-02-04/attendance.csv'
attendance = pd.read_csv(url,sep=",") # use sep="," for coma separation. 
attendance.describe()
# Out:
#                year         total           home           away          week  \
# count  10846.000000  1.084600e+04   10846.000000   10846.000000  10846.000000
# mean    2009.528213  1.080910e+06  540455.012539  540455.012539      9.000000
# std        5.753415  7.287697e+04   66774.652550   25509.325673      4.899205
# min     2000.000000  7.606440e+05  202687.000000  450295.000000      1.000000
# 25%     2005.000000  1.040509e+06  504360.000000  524974.000000      5.000000
# 50%     2010.000000  1.081090e+06  543185.000000  541757.000000      9.000000
# 75%     2015.000000  1.123230e+06  578342.000000  557741.000000     13.000000
# max     2019.000000  1.322087e+06  741775.000000  601655.000000     17.000000
#
#        weekly_attendance
# count       10208.000000
# mean        67556.876567
# std          9022.015325
# min         23127.000000
# 25%         63245.500000
# 50%         68334.000000
# 75%         72544.750000
# max        105121.000000

# %%
## Loading the standings data
url='https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-02-04/standings.csv'
standings = pd.read_csv(url,sep=",") # use sep="," for coma separation. 
standings.describe()
# Out:
#               year        wins        loss  points_for  points_against  \
# count   638.000000  638.000000  638.000000  638.000000      638.000000
# mean   2009.528213    7.984326    7.984326  350.283699      350.283699
# std       5.757664    3.083822    3.083313   71.399067       59.546661
# min    2000.000000    0.000000    0.000000  161.000000      165.000000
# 25%    2005.000000    6.000000    6.000000  299.000000      310.000000
# 50%    2010.000000    8.000000    8.000000  348.000000      347.000000
# 75%    2014.750000   10.000000   10.000000  396.000000      391.500000
# max    2019.000000   16.000000   16.000000  606.000000      517.000000
#
#        points_differential  margin_of_victory  strength_of_schedule  \
# count           638.000000         638.000000            638.000000
# mean              0.000000          -0.001881              0.001097
# std             101.088938           6.323133              1.634369
# min            -261.000000         -16.300000             -4.600000
# 25%             -75.000000          -4.700000             -1.100000
# 50%               1.500000           0.100000              0.000000
# 75%              72.750000           4.575000              1.200000
# max             315.000000          19.700000              4.300000
#
#        simple_rating  offensive_ranking  defensive_ranking
# count   6.380000e+02         638.000000         638.000000
# mean   -6.682220e-17          -0.000157          -0.001097
# std     6.200334e+00           4.340017           3.566280
# min    -1.740000e+01         -11.700000          -9.800000
# 25%    -4.475000e+00          -3.175000          -2.400000
# 50%     0.000000e+00           0.000000           0.100000
# 75%     4.500000e+00           2.700000           2.500000
# max     2.010000e+01          15.900000           9.800000

# %%
## Loading the games data
url='https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-02-04/games.csv'
games = pd.read_csv(url,sep=",") # use sep="," for coma separation. 
games.describe()
# Out:
#               year      pts_win     pts_loss      yds_win  turnovers_win  \
# count  5324.000000  5324.000000  5324.000000  5324.000000    5324.000000
# mean   2009.527047    27.781555    16.088843   361.635612       1.080203
# std       5.754236     8.830090     8.137451    78.581154       1.037956
# min    2000.000000     3.000000     0.000000    47.000000       0.000000
# 25%    2005.000000    21.000000    10.000000   308.000000       0.000000
# 50%    2010.000000    27.000000    16.000000   361.000000       1.000000
# 75%    2015.000000    34.000000    21.000000   415.000000       2.000000
# max    2019.000000    62.000000    51.000000   653.000000       7.000000
#
#           yds_loss  turnovers_loss
# count  5324.000000     5324.000000
# mean    309.080579        2.167543
# std      84.497085        1.421141
# min      26.000000        0.000000
# 25%     251.000000        1.000000
# 50%     306.000000        2.000000
# 75%     366.000000        3.000000
# max     613.000000        8.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
df_num = attendance.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    year   total    home    away  week  weekly_attendance
# 0  2000  893926  387475  506451     1            77434.0
# 1  2000  893926  387475  506451     2            66009.0
# 2  2000  893926  387475  506451     3                NaN
# 3  2000  893926  387475  506451     4            71801.0
# 4  2000  893926  387475  506451     5            66985.0

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
from siuba import *
from plotnine import *

# %%
weekly_attendance = (attendance 
                    >> group_by(_.year,_.week)
                    >> summarize(attendance = _.weekly_attendance.mean())
                    >> mutate(year = _.year.astype(str)))

weekly_attendance.head(10)
# Out:
#    year  week    attendance
# 0  2000     1  66529.933333
# 1  2000     2  67141.533333
# 2  2000     3  68332.000000
# 3  2000     4  63450.642857
# 4  2000     5  70714.785714
# 5  2000     6  64802.714286
# 6  2000     7  65462.857143
# 7  2000     8  65518.285714
# 8  2000     9  65369.285714
# 9  2000    10  65361.333333

# %%
(
weekly_attendance 
    >> ggplot(aes("week","attendance",color="year"))
    + geom_line()
)
# Out:
# <ggplot: (319563017)>

# %%
attendance.head()
# Out:
#       team  team_name  year   total    home    away  week  weekly_attendance
# 0  Arizona  Cardinals  2000  893926  387475  506451     1            77434.0
# 1  Arizona  Cardinals  2000  893926  387475  506451     2            66009.0
# 2  Arizona  Cardinals  2000  893926  387475  506451     3                NaN
# 3  Arizona  Cardinals  2000  893926  387475  506451     4            71801.0
# 4  Arizona  Cardinals  2000  893926  387475  506451     5            66985.0

# %%
team_attendance = (attendance 
    >> filter(_.year >= 2015)
    >> group_by(_.team_name)
    >> summarize(avg_attendance = _.weekly_attendance.mean)
                  )

(
team_attendance
    >> ggplot(aes(x="team_name",y="avg_attendance"))
    + geom_bar(stat='identity')

)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/mizani/scale.py in train(cls, new_data, old, drop, na_rm)
#     215             try:
# --> 216                 new = np.unique(new_data)
#     217                 new.sort()
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     309     else:
# --> 310         ar.sort()
#     311         aux = ar
#
# TypeError: '<' not supported between instances of 'method' and 'method'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     695     """A pprint that just redirects to the normal repr function."""
#     696     # Find newlines and replace them with p.break_()
# --> 697     output = repr(obj)
#     698     for idx,output_line in enumerate(output.splitlines()):
#     699         if idx:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/ggplot.py in __repr__(self)
#      86         # in the jupyter notebook.
#      87         if not self.figure:
# ---> 88             self.draw()
#      89         plt.show()
#      90         return '<ggplot: (%d)>' % self.__hash__()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/ggplot.py in draw(self, return_ggplot)
#     179         # new frames knowing that they are separate from the original.
#     180         with pd.option_context('mode.chained_assignment', None):
# --> 181             return self._draw(return_ggplot)
#     182
#     183     def _draw(self, return_ggplot=False):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     186         # assign a default theme
#     187         self = deepcopy(self)
# --> 188         self._build()
#     189
#     190         # If no theme we use the default
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/ggplot.py in _build(self)
#     293         # Map and train positions so that statistics have access
#     294         # to ranges and all positions are numeric
# --> 295         layout.train_position(layers, scales.x, scales.y)
#     296         layout.map_position(layers)
#     297
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/facets/layout.py in train_position(self, layers, x_scale, y_scale)
#      86             self.panel_scales_y = result.y
#      87
# ---> 88         self.facet.train_position_scales(self, layers)
#      89
#      90     def map_position(self, layers):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/facets/facet.py in train_position_scales(self, layout, layers)
#     232                 # the scale index for each data point
#     233                 SCALE_Y = _layout['SCALE_Y'].iloc[match_id].tolist()
# --> 234                 panel_scales_y.train(data, y_vars, SCALE_Y)
#     235
#     236         return self
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/scales/scales.py in train(self, data, vars, idx)
#     120             for i, sc in enumerate(self, start=1):
#     121                 bool_idx = (i == idx)
# --> 122                 sc.train(data.loc[bool_idx, col])
#     123
#     124     def map(self, data, vars, idx):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/scales/scale_xy.py in train(self, series)
#      67             self.range_c.train(series)
#      68         else:
# ---> 69             self.range.train(series, drop=self.drop)
#      70
#      71     def map(self, series, limits=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/scales/range.py in train(self, x, drop, na_rm)
#      41         Train discrete range
#      42         """
# ---> 43         self.range = scale_discrete.train(x, self.range, drop, na_rm=na_rm)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/mizani/scale.py in train(cls, new_data, old, drop, na_rm)
#     218             except TypeError:
#     219                 # new_data probably has nans and other types
# --> 220                 new = list(set(new_data))
#     221                 new = multitype_sort(new)
#     222
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __hash__(self)
#    1885         raise TypeError(
#    1886             "{0!r} objects are mutable, thus they cannot be"
# -> 1887             " hashed".format(self.__class__.__name__)
#    1888         )
#    1889
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
